# %%
# %sql
DROP TABLE IF EXISTS gold.fato_reserva;
DROP TABLE IF EXISTS gold.dim_cliente;
DROP TABLE IF EXISTS gold.dim_carro;
DROP TABLE IF EXISTS gold.dim_localidade;
DROP TABLE IF EXISTS gold.dim_tempo;

# %%
# %sql
DROP TABLE IF EXISTS silver.categoria;
DROP TABLE IF EXISTS silver.marca;
DROP TABLE IF EXISTS silver.modelo;
DROP TABLE IF EXISTS silver.estado;
DROP TABLE IF EXISTS silver.cidade;
DROP TABLE IF EXISTS silver.agencia;
DROP TABLE IF EXISTS silver.cliente;
DROP TABLE IF EXISTS silver.carro;
DROP TABLE IF EXISTS silver.reserva;
DROP TABLE IF EXISTS silver.pagamento;

# %%
# %sql
DROP TABLE IF EXISTS bronze.categoria;
DROP TABLE IF EXISTS bronze.marca;
DROP TABLE IF EXISTS bronze.modelo;
DROP TABLE IF EXISTS bronze.estado;
DROP TABLE IF EXISTS bronze.cidade;
DROP TABLE IF EXISTS bronze.agencia;
DROP TABLE IF EXISTS bronze.cliente;
DROP TABLE IF EXISTS bronze.carro;
DROP TABLE IF EXISTS bronze.reserva;
DROP TABLE IF EXISTS bronze.pagamento;

# %% [markdown]
# Apagar arquivos do Landing:

# %%
dbutils.fs.rm("/Volumes/workspace/landing/dados/", recurse=True)

# %% [markdown]
# Apagar schemas:

# %%
# %sql
DROP SCHEMA IF EXISTS gold;
DROP SCHEMA IF EXISTS silver;
DROP SCHEMA IF EXISTS bronze;
DROP VOLUME IF EXISTS workspace.landing.dados;
DROP SCHEMA IF EXISTS landing;
